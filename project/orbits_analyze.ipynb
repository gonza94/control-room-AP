# %%
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
mpl.rcParams['mathtext.fontset'] = 'stix'
mpl.rcParams['font.family'] = 'STIXGeneral'

# %%
x0 = np.loadtxt('xnoerror.txt')
y0 = np.loadtxt('ynoerror.txt')

xnew = np.loadtxt('xerror.txt')
ynew = np.loadtxt('yerror.txt')

# %%
bpmpositions = np.loadtxt('bpmpositionsCCL.txt',dtype = 'str',delimiter = ',')
keys = [i[-6:] for i in bpmpositions[:,0]]
values1 = np.array([float(i) for i in bpmpositions[:,1]])
values2 = np.array([float(i) for i in bpmpositions[:,2]])
values = values1+values2

bpmdict = dict(zip(keys, values))

# %%
fig,ax = plt.subplots(1,1,figsize = (8,6))

ax.plot(bpmdict.keys(),x0,'--',label = 'Bare Machine')
ax.plot(bpmdict.keys(),xnew,label = 'With DTL Error')
#ax.plot(bpmdicts.keys(),datacorr[:,1]*1000,label = 'Corrected')

ax.set_xlabel('CCL BPMs',fontsize = 30)
ax.set_ylabel('Horizontal Orbit [mm]',fontsize = 30)

#ax.set_title('PyORBIT Tracking with Transfer Matrix Approach',fontsize = 20)

ax.tick_params(axis='both',labelsize=24)

ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)

ax.legend(fontsize = 20)

plt.show()
plt.close()
# Out:
# /var/folders/42/7sv6hz7577n5zy69jc4nkh300000gn/T/ipykernel_53722/948036960.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)

# %%
fig,ax = plt.subplots(1,1,figsize = (8,6))

ax.plot(bpmdict.keys(),y0,'--',label = 'Bare Machine')
ax.plot(bpmdict.keys(),ynew,label = 'With DTL Error')
#ax.plot(bpmdicts.keys(),datacorr[:,1]*1000,label = 'Corrected')

ax.set_xlabel('CCL BPMs',fontsize = 30)
ax.set_ylabel('Vertical Orbit [mm]',fontsize = 30)

#ax.set_title('PyORBIT Tracking with Transfer Matrix Approach',fontsize = 20)

ax.tick_params(axis='both',labelsize=24)

ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)

ax.legend(fontsize = 20)

plt.show()
plt.close()
# Out:
# /var/folders/42/7sv6hz7577n5zy69jc4nkh300000gn/T/ipykernel_53722/2917976050.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)

# %%
dataopt = np.loadtxt('optimizerLM.txt')
datalsq = np.loadtxt('lsq.txt')

# %%
dataopt
# Out:
# array([[-7.94132146e-02,  2.45537690e-01,  3.78550493e+01],
#        [ 1.13094848e-01, -7.96380699e-04,  3.78707470e+01],
#        [ 4.90930924e-05,  5.42904563e-06,  3.78647124e+01],
#        [ 1.23073536e-04,  1.13070891e-05,  3.78534313e+01],
#        [ 7.15711884e-05,  1.13398988e-05,  3.78631688e+01],
#        [ 1.18243415e-04, -2.68620358e-05,  3.78730632e+01],
#        [ 1.38790262e-05,  7.37382976e-05,  3.78725629e+01],
#        [ 1.66578478e-04,  2.56495199e-05,  3.78632171e+01],
#        [-3.75606685e-05, -1.17824766e-04,  3.78724404e+01],
#        [-7.13399577e-03, -4.30242154e-04,  3.78655300e+01]])

# %%
fig,ax = plt.subplots(1,1,figsize = (8,6))

ax.plot(bpmdict.keys(),y0,'--',label = 'Bare Machine')
ax.plot(bpmdict.keys(),ynew,label = 'With DTL Error')
ax.plot(bpmdict.keys(),dataopt[:,1],label = 'LM Optimization')
ax.plot(bpmdict.keys(),datalsq[:,1],label = 'LSQ')

#ax.plot(bpmdicts.keys(),datacorr[:,1]*1000,label = 'Corrected')

ax.set_xlabel('CCL BPMs',fontsize = 30)
ax.set_ylabel('Vertical Orbit [mm]',fontsize = 30)

#ax.set_title('PyORBIT Tracking with Transfer Matrix Approach',fontsize = 20)

ax.tick_params(axis='both',labelsize=24)

ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)

ax.legend(fontsize = 16)

plt.show()
plt.close()
# Out:
# /var/folders/42/7sv6hz7577n5zy69jc4nkh300000gn/T/ipykernel_53722/261116318.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)

# %%
fig,ax = plt.subplots(1,1,figsize = (8,6))

ax.plot(bpmdict.keys(),x0,'--',label = 'Bare Machine')
ax.plot(bpmdict.keys(),xnew,label = 'With DTL Error')
ax.plot(bpmdict.keys(),dataopt[:,0],label = 'LM Optimization')
ax.plot(bpmdict.keys(),datalsq[:,0],label = 'LSQ')
#ax.plot(bpmdicts.keys(),datacorr[:,1]*1000,label = 'Corrected')

ax.set_xlabel('CCL BPMs',fontsize = 30)
ax.set_ylabel('Horizontal Orbit [mm]',fontsize = 30)

#ax.set_title('PyORBIT Tracking with Transfer Matrix Approach',fontsize = 20)

ax.tick_params(axis='both',labelsize=24)

ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)

ax.legend(fontsize = 16)

plt.show()
plt.close()
# Out:
# /var/folders/42/7sv6hz7577n5zy69jc4nkh300000gn/T/ipykernel_53722/4168012812.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
